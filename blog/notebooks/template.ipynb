# %% [markdown]
# ---
# title: Notebook post title
# description: A short description shown on the blog index.
# lang: en
# categories:
#   - Python
# ---
#
# Write a short introduction here.

# %% [markdown]
# ## A section
#
# Explain what the following code does.

# %%
result = 2 + 2
result
# Out:
# 4
